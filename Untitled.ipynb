# %%
import pandas as pd

# %% [markdown]
# # 1 Read a .csv from a URL with Pandas
#
# *Target website:* [https://www.football-data.co.uk/data.php](https://www.football-data.co.uk/data.php)

# %%
#reading 1 csv file from the website

df_premier24=pd.read_csv('https://www.football-data.co.uk/mmz4281/2425/E0.csv')

# %%
#showing dataframe
df_premier24
# Out:
#     Div        Date   Time       HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    E0  16/08/2024  20:00     Man United       Fulham     1     0   H     0
# 1    E0  17/08/2024  12:30        Ipswich    Liverpool     0     2   A     0
# 2    E0  17/08/2024  15:00        Arsenal       Wolves     2     0   H     1
# 3    E0  17/08/2024  15:00        Everton     Brighton     0     3   A     0
# 4    E0  17/08/2024  15:00      Newcastle  Southampton     1     0   H     1
# ..   ..         ...    ...            ...          ...   ...   ...  ..   ...
# 375  E0  25/05/2025  16:00      Newcastle      Everton     0     1   A     0
# 376  E0  25/05/2025  16:00  Nott'm Forest      Chelsea     0     1   A     0
# 377  E0  25/05/2025  16:00    Southampton      Arsenal     1     2   A     0
# 378  E0  25/05/2025  16:00      Tottenham     Brighton     1     4   A     1
# 379  E0  25/05/2025  16:00         Wolves    Brentford     1     1   D     0
#
# ...

# %%
# rename colums
df_premier24.rename(columns={'FTHG':'coln1',
                             'FTAG':'coln2'},inplace=True)

# %%
df_premier24
# Out:
#     Div        Date   Time       HomeTeam     AwayTeam  coln1  coln2 FTR  \
# 0    E0  16/08/2024  20:00     Man United       Fulham      1      0   H
# 1    E0  17/08/2024  12:30        Ipswich    Liverpool      0      2   A
# 2    E0  17/08/2024  15:00        Arsenal       Wolves      2      0   H
# 3    E0  17/08/2024  15:00        Everton     Brighton      0      3   A
# 4    E0  17/08/2024  15:00      Newcastle  Southampton      1      0   H
# ..   ..         ...    ...            ...          ...    ...    ...  ..
# 375  E0  25/05/2025  16:00      Newcastle      Everton      0      1   A
# 376  E0  25/05/2025  16:00  Nott'm Forest      Chelsea      0      1   A
# 377  E0  25/05/2025  16:00    Southampton      Arsenal      1      2   A
# 378  E0  25/05/2025  16:00      Tottenham     Brighton      1      4   A
# 379  E0  25/05/2025  16:00         Wolves    Brentford      1      1   D
#
#      HTHG  HTAG  ... B365CAHH B365CAHA  PCAHH  PCAHA  MaxCAHH  MaxCAHA  \
# ...
